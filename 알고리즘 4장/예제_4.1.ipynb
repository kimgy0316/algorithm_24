# %% [markdown]
# ### 1) 문제 정의 (MD)

# %% [markdown]
# ##### 팩토리얼(하향식 축소 정복 기법)

# %% [markdown]
# ###  2) 알고리즘 설명  (MD)

# %% [markdown]
# ##### 축소 정복 기법 : 주어진 문제를 해결하기 위해 이 문제와 좀 더 작은 문제간의 관계를 이용하는 전략 (하향식 : 보통 순환구조를 이용)

# %% [markdown]
# ###  3) 손으로 푼 예제 (MD, 이미지 삽입)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4) 코드 개요(입력 변수, 출력, 함수 설명) (MD)

# %% [markdown]
# ##### 1) 함수명 : def factorial_recur(n), 축소 정복 기법: 하향식 접근
# ##### 2) 입력 변수: n값을 받는다
# ##### 3) 반환값 : n값이 1이면 1을 반환하고, 1이 아니면 n값에서 -1을 하여 n값이 1이될 때까지 함수를 반복한다.

# %% [markdown]
# ### 5) 코드 (PY,C)

# %%
def factorual_recur(n) :
    if n == 1 :
        return 1
    else :
        return (n*factorual_recur(n-1))

# %% [markdown]
# ### 6) 테스트 코드  (PY,C) , 입력을 바꾸어서

# %%
def factorial_recur(n):
    if n == 1:
        return 1
    else:
        return n * factorial_recur(n - 1)

print(f"10!는 {factorial_recur(10)}")
# Out:
# 10!는 3628800

# %% [markdown]
# ### 7) 수행 결과 (MD, 결과 캡춰하여 이미지로 삽입)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8) 복잡도 분석 (MD)

# %% [markdown]
# ##### O(n)

# %% [markdown]
# ### 9) 협력 내용(조별, 팀별)

# %% [markdown]
# ##### 실습시간 중 이해가 되지 않는 부분에 대해 팀원들과 모여 상의하며 문제를 해결해 나아갔습니다.
