# %% [markdown]
# ### 1) 문제 정의 (MD)

# %% [markdown]
# 이진트리의 표준 순회 문제

# %% [markdown]
# ###  2) 알고리즘 설명  (MD)

# %% [markdown]
# 트리의 모든 노드를 한 번씩 방문하는 작업을 말하는데, 이진트리의 기본 순회에는 전위, 중위, 후위의 3가지 방법이 있다. 이들은 루트와 왼쪽 서브 트리, 오른쪽 서브 트리를 각각 어떤 순서로 방문하느냐에 따라 구분된다.

# %% [markdown]
# ###  3) 손으로 푼 예제 (MD, 이미지 삽입)

# %% [markdown]
# ### 4) 코드 개요(입력 변수, 출력, 함수 설명) (MD)

# %% [markdown]
# 1) 입력 변수 : n
# 2) 출력 변수 : n.left, n.right
# 3) 함수 설명 : def inorder(n) >> 중위 순회 함수
#                def preorder(n) >> 전위 순회 함수
#                def postorder(n) >> 후위 순회 함수

# %% [markdown]
# ### 5) 코드 (PY,C)

# %%
class TNode:
    def __init__(self, data, left=None, right=None):
        self.data = data
        self.left = left
        self.right = right

def inorder(n):
    if n is not None:
        inorder(n.left)
        print(n.data, end='')
        inorder(n.right)

def preorder(n):
    if n is not None:
        print(n.data, end='')
        preorder(n.left)
        preorder(n.right)

def postorder(n):
    if n is not None:
        postorder(n.left)
        postorder(n.right)
        print(n.data, end='')

# %% [markdown]
# ### 6) 테스트 코드  (PY,C) , 입력을 바꾸어서

# %%
d=TNode('D', None, None)
e=TNode('E', None, None)
b=TNode('B', d, e)
f=TNode('F', None, None)
c=TNode('C', f, None)
root=TNode('A', b, c)
print('In-Order : ', end='')
inorder(root)
print()
print('Pre-Order : ', end='')
inorder(root)
print()
print('Post-Order : ', end='')
inorder(root)
print()
# Out:
# In-Order : DBEAFC
# Pre-Order : DBEAFC
# Post-Order : DBEAFC

# %% [markdown]
# ### 7) 수행 결과 (MD, 결과 캡춰하여 이미지로 삽입)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8) 복잡도 분석 (MD)

# %% [markdown]
# O(n)
# 각 알고리즘에서 출력문 을 기본 연산으로 하면 복잡도 함수는 명확히 T(n)=n이다.

# %% [markdown]
# ### 9) 협력 내용(조별, 팀별)

# %% [markdown]
# 실습시간 중 이해가 되지 않는 부분에 대해 팀원들과 모여 상의하며 문제를 해결해 나아갔습니다.
