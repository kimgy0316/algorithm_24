# %% [markdown]
# ### 1) 문제 정의

# %% [markdown]
# 선형조사법을 이용해 해시 테이블의 k 위치를 살피고 빈 공간이 있으면 저장한다. 빈 공간이 나올때까지 계속하고 끝에 도달하면 처음으로 돌아간다.

# %% [markdown]
# ### 2) 알고리즘 설명

# %% [markdown]
# 선형조사법 (해시 함수로 계산된 버킷에 빈 슬롯이 없으면 그 다음 버킷들을 순차적으로 조사하여 빈 슬롯이 있는지 찾는다. 이때 비어 있는 공간을 찾는것을 조사라고 한다.) 조사 과정에서 처음 충돌이 발생한 곳으로 돌아왔다면 테이블이 가득 찬 상태이다.

# %% [markdown]
# ### 3) 손으로 푼 예제

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4) 코드 개요

# %% [markdown]
# 함수명:
# def hashFn(key)
# def lp_insert(key)
# def lp_search(key)
# def lp_delete(key)
# 입력,출력값:
# print(" 최초: ",table)
# lp_insert(45); print("45 삽입: ", table)
# lp_insert(27); print("27 삽입: ", table)
# lp_insert(88); print("88 삽입: ", table)
# lp_insert(9); print("9 삽입: ", table)
# lp_insert(71); print("71 삽입: ", table)
# lp_insert(60); print("60 삽입: ", table)
# lp_insert(46); print("46 삽입: ", table)
# lp_insert(38); print("38 삽입: ", table)
# lp_insert(24); print("24 삽입: ", table)
# lp_delete(60); print("60 삭제:",table)
# print("46탐색:",lp_search(46))
#
# 설명:
# 테이블 크기를 입력하고 해시 함수로 레코드가 저장될 위치를 구한다.
# 삽입:해시 주소를 저장하고 테이블이 비어있지 않으면 +1로 다음위치로 이동시킨다.
# 비어있는 버킷을 찾으면 해당 슬롯을 항목에 저장한다.
# 탐색: 찾는 항목이 테이블에 있으면 주소값을 반환하고, 없으면 +1씩 올리면서 위치를 검사해 반환한다.
# 삭제: 해당 버킷의 키가 있으면 그 항목을 삭제하고, -1로 처리한다.

# %% [markdown]
# ### 5) 코드

# %%
M =13
table = [None]*M
def hashFn(key):
    return key % M

def lp_insert(key):
    id = hashFn(key)
    count = M
    while count >0 and (table[id] != None):
        id = (id+1+M) %M
        count -=1
    if count >0:
        table[id] =key
    return 

def lp_search(key):
    id = hashFn(key)
    count = M
    while count >0:
        if table[id] == None :
            return None
        if table[id] == key:
            return table[id]
        id = (id+1+M)%M
        count -=1
    return None

def lp_delete(key):
    id = hashFn(key)
    count = M
    while count >0:
        if table[id] == None: return 
        if table[id] != -1 and table[id] ==key:
            table[id] = -1
            return 
        id = (id+1+M) % M
        count -=1

print(" 최초: ",table)
lp_insert(45); print("45 삽입: ", table)
lp_insert(27); print("27 삽입: ", table)
lp_insert(88); print("88 삽입: ", table)
lp_insert(9); print("9 삽입: ", table)
lp_insert(71); print("71 삽입: ", table)
lp_insert(60); print("60 삽입: ", table)
lp_insert(46); print("46 삽입: ", table)
lp_insert(38); print("38 삽입: ", table)
lp_insert(24); print("24 삽입: ", table)
lp_delete(60); print("60 삭제:",table)
print("46탐색:",lp_search(46))

# %% [markdown]
# ### 6) 테스트 코드

# %%
M =13
table = [None]*M
def hashFn(key):
    return key % M

def lp_insert(key):
    id = hashFn(key)
    count = M
    while count >0 and (table[id] != None):
        id = (id+1+M) %M
        count -=1
    if count >0:
        table[id] =key
    return 

def lp_search(key):
    id = hashFn(key)
    count = M
    while count >0:
        if table[id] == None :
            return None
        if table[id] == key:
            return table[id]
        id = (id+1+M)%M
        count -=1
    return None

def lp_delete(key):
    id = hashFn(key)
    count = M
    while count >0:
        if table[id] == None: return 
        if table[id] != -1 and table[id] ==key:
            table[id] = -1
            return 
        id = (id+1+M) % M
        count -=1

print(" 최초: ",table)
lp_insert(15); print("15 삽입: ", table)
lp_insert(27); print("27 삽입: ", table)
lp_insert(78); print("78 삽입: ", table)
lp_insert(9); print("9 삽입: ", table)
lp_insert(71); print("71 삽입: ", table)
lp_insert(80); print("80 삽입: ", table)
lp_insert(46); print("46 삽입: ", table)
lp_insert(30); print("30 삽입: ", table)
lp_insert(14); print("24 삽입: ", table)
lp_delete(30); print("30 삭제:",table)
print("14탐색:",lp_search(14))
# Out:
#  최초:  [None, None, None, None, None, None, None, None, None, None, None, None, None]
# 15 삽입:  [None, None, 15, None, None, None, None, None, None, None, None, None, None]
# 27 삽입:  [None, 27, 15, None, None, None, None, None, None, None, None, None, None]
# 78 삽입:  [78, 27, 15, None, None, None, None, None, None, None, None, None, None]
# 9 삽입:  [78, 27, 15, None, None, None, None, None, None, 9, None, None, None]
# 71 삽입:  [78, 27, 15, None, None, None, 71, None, None, 9, None, None, None]
# 80 삽입:  [78, 27, 15, 80, None, None, 71, None, None, 9, None, None, None]
# 46 삽입:  [78, 27, 15, 80, None, None, 71, 46, None, 9, None, None, None]
# 30 삽입:  [78, 27, 15, 80, 30, None, 71, 46, None, 9, None, None, None]
# 24 삽입:  [78, 27, 15, 80, 30, 14, 71, 46, None, 9, None, None, None]
# 30 삭제: [78, 27, 15, 80, -1, 14, 71, 46, None, 9, None, None, None]
# 14탐색: 14

# %% [markdown]
# ### 7) 실행결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8) 복잡도 분석

# %% [markdown]
# O(n)

# %% [markdown]
# ### 9) 협력내용

# %% [markdown]
# 실습시간 중 이해가 되지 않는 부분에 대해 팀원들과 모여 상의하며 문제를 해결해 나아갔습니다.
